# %% [markdown]
# # 🎲🔍 Unveiling the Secrets of the Marble Game! 🧲✨
#
# Ever wondered about the fascinating world of probability and combinations in a marble game? 🤔 Today, I stumbled upon a captivating video (http://xhslink.com/vKiXow) showcasing a unique twist to the classic game.
#
# 🌈 Here's the scoop:
# 3 colors of marbles 🟥🔵🟢, each with 8 pieces.
# The challenge? Draw 12 marbles and uncover if your color combination matches the winning criteria.
# The stakes? Pay 10 units if you get '345' (e.g., 3 red, 4 blue, 5 green).
#
# 💰 But wait, there's more:
# The ultimate prize of 100 units awaits those who score 4 marbles or 8 marbles with two distinct colors. 🏆💸
#
# 🤯 Mind-blowing Insights:
# I delved into the game's intricacies using Python, generating all possible combinations and comparing them to the winning criteria. The results were nothing short of shocking! 🐍📊
#
# 👉 Curious to uncover the Python magic?
# Check out the code and unravel the secrets behind the marble game on this link! 🔗 https://lnkd.in/g76UvhET
#
# 🔮 Get ready to redefine your approach to marble games and embrace the power of probability! 🚀🔢
# #MarbleGame #ProbabilityMagic #DataScienceFun #GameChanger
#
# 🌟 Psst, a little insider info: I had a great coding ally in ChatGPT. It effortlessly translated my thoughts into code and crafted this post exactly the way I envisioned. Just told it what to do, and magic happened! 🚀💻 #CodingWithChatGPT

# %%
from IPython.display import Image
image_path = 'D:/martin/python_code/just4fun/marble_win.jpg'
Image(filename=image_path)

# %%
from itertools import combinations

# Sample list
n=8
my_list = n*['R']+n*['G']+n*['B']

# Generate all possible combinations of length 2
result = list(combinations(my_list, 12))

# Display the result
#print(result)

# %%
len(result)
# Out:
# 2704156

# %%
from collections import Counter

combination={}

for i in result:
    element_counts = Counter(i)
    key=''.join(map(str, sorted(list(element_counts.values()))))
    
    if key in combination:
        combination[key] += 1
    else:
        combination[key] = 1

# %%
# Sort the dictionary by values in descending order
sorted_dict = dict(sorted(combination.items(), key=lambda item: item[1], reverse=True))

sorted_dict
# Out:
# {'345': 1317120,
#  '444': 343000,
#  '246': 329280,
#  '336': 263424,
#  '255': 263424,
#  '237': 75264,
#  '156': 75264,
#  '147': 26880,
#  '138': 2688,
#  '57': 2688,
#  '228': 2352,
#  '66': 2352,
#  '48': 420}

# %%
import matplotlib.pyplot as plt

# Extract labels and values from the dictionary
labels = list(sorted_dict.keys())
values = list(sorted_dict.values())

# %%
# Calculate the total sum for percentage calculation
total_sum = sum(values)

# Calculate percentages
percentages = [(value / total_sum) * 100 for value in values]

# Plotting the bar chart
fig, ax = plt.subplots(figsize=(10, 6))
bars = ax.bar(labels, percentages)

# Adding percentage values above each bar
for bar, percentage in zip(bars, percentages):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, height + 0.5, f'{percentage:.2f}%', ha='center', va='bottom')

plt.xlabel('Categories')
plt.ylabel('Percentage')
plt.title('Distribution of Values')
plt.show()

# %%
# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(values, labels=None, autopct='%1.1f%%', startangle=140, labeldistance=1.1)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

# Adding legend outside the pie chart
plt.legend(labels, loc='center left', bbox_to_anchor=(1, 0.5))

plt.title('Distribution of Values')
plt.show()
